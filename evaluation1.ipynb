# %% [markdown]
# <a href="https://colab.research.google.com/github/Malatesh-kalled/python_machine_learning/blob/main/evaluation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Load the dataset from a CSV file
data = pd.read_csv('/content/drive/MyDrive/data.csv')

# Assuming your CSV file has two columns 'Feature' and 'Target'
X = data[['feature']]
y = data['target']

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Plot the data and the regression line
plt.scatter(X, y, label='Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()
plt.show()

# Interpret Results
coefficients = model.coef_
intercept = model.intercept_
print("Slope (Coefficient):", coefficients[0])
print("Intercept:", intercept)
# Out:
# Slope (Coefficient): 1.9754768392370567
# Intercept: -1.1934604904632113

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
