# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data = pd.read_excel('/content/drive/MyDrive/data.xlsx')

X = data[['x1', 'x2', 'x3']].values
y = data['y'].values

correlation_matrix = data.corr()
correlation_with_y = correlation_matrix['y']

print("Correlation between features and Y:")
print(correlation_with_y)

model = LinearRegression()
model.fit(X, y)

coefficients = model.coef_
intercept = model.intercept_

print("Coefficients:", coefficients)
print("Intercept:", intercept)

predictions = model.predict(X)

plt.scatter(y, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions')
plt.show()
# Out:
# Correlation between features and Y:
# x1    0.992379
# x2    0.985138
# x3    0.977423
# y     1.000000
# Name: y, dtype: float64
# Coefficients: [0.70956675 0.29070845 0.05348903]
# Intercept: -2.1334336271820735
