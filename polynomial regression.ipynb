# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

data = pd.read_excel('/content/drive/MyDrive/data.xlsx')

X = data[['x1', 'x2', 'x3']].values
y = data['y'].values

correlation_matrix = data.corr()
correlation_with_y = correlation_matrix['y']

print("Correlation between features and Y:")
print(correlation_with_y)

degree = 2
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

coefficients = model.coef_
intercept = model.intercept_

print("Coefficients:", coefficients)
print("Intercept:", intercept)

predictions = model.predict(X_poly)

plt.scatter(y, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions')
plt.show()
# Out:
# Correlation between features and Y:
# x1    0.987012
# x2    0.986577
# x3    0.991048
# y     1.000000
# Name: y, dtype: float64
# Coefficients: [ 1.92953292e-13  1.64584976e+00  1.50714524e+00  2.04380742e-01
#   3.39881637e-01 -1.39903506e+00  5.09529768e-01  1.63148126e+00
#  -1.54534452e+00  4.16471763e-01]
# Intercept: -15.250946066764644
